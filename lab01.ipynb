# %%
import pandas as pd
datadf = pd.read_csv('data.csv')
datadf
# Out:
#         ID    Name in English     Name in French      Name in Spanish  \
# 0     1022      South Italian     italien du sud  napolitano-calabrés
# 1     1023           Sicilian           sicilien            siciliano
# 2      383          Low Saxon          bas-saxon           bajo sajón
# 3      335         Belarusian         biélorusse           bielorruso
# 4      382            Lombard            lombard             lombardo
# ...    ...                ...                ...                  ...
# 2717  1972           Yonaguni           yonaguni             yonaguni
# 2718  2018             Yucuna             yucuna               yucuna
# 2719  2015  Yurutí (Colombia)  yurutí (Colombie)    yurutí (Colombia)
# 2720  2716          Zangskari          zangskari            zangskari
# 2721  2177            Zidgali            zidgali              zidgali
#
#                                               Countries  \
# 0                                                 Italy
# ...

# %%
Freq = datadf['Degree of endangerment'].value_counts()
Freq
# Out:
# Definitely endangered    680
# Vulnerable               628
# Critically endangered    607
# Severely endangered      554
# Extinct                  253
# Name: Degree of endangerment, dtype: int64

# %%
import matplotlib.pyplot as plt
Freq.plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
eac = ['Kenya', 'Ethiopia', 'Uganda', 'Rwanda', 'Burundi', 'Sudan']
filt = datadf[datadf.Countries.isin(eac)]
filt
# Out:
#         ID Name in English Name in French Name in Spanish Countries  \
# 185    700          Heiban         heiban          heibán     Sudan
# 195   1686             Yem            yem           yemsa  Ethiopia
# 207   1713         Acheron        acheron         acheron     Sudan
# 257     60           Lumun          lumun           lomón     Sudan
# 273     70            Laro           Laru            laro     Sudan
# ...    ...             ...            ...             ...       ...
# 2476    87        Qwarenya       qwarenya        qwarenya  Ethiopia
# 2485   108           Singa          singa           singa    Uganda
# 2502  1738          Togoyo         togoyo          togoyo     Sudan
# 2524    94           Yaaku          yaaku           yaaku     Kenya
# 2679    97           Sogoo          sogoo           sogoo     Kenya
#
#      Country codes alpha 3 ISO639-3 codes Degree of endangerment  \
# 185                    SDN            hbn             Vulnerable
# ...

# %%
level = filt['Degree of endangerment'].value_counts()
level
# Out:
# Severely endangered      28
# Definitely endangered    22
# Critically endangered    22
# Extinct                  18
# Vulnerable               15
# Name: Degree of endangerment, dtype: int64

# %%
level.plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
ag = ['Angola']
cdf = datadf[datadf.Countries.isin(ag)]
cdf
# Out:
#        ID Name in English Name in French Name in Spanish Countries  \
# 891   127            Bolo           bolo            bolo    Angola
# 2385  126            Kede           kede            kede    Angola
# 2402  124           Kwadi          kwadi           kuadí    Angola
# 2403  125           Kwisi          kwisi           kwisi    Angola
#
#      Country codes alpha 3 ISO639-3 codes Degree of endangerment  \
# 891                    ANG            blv  Definitely endangered
# 2385                   ANG            NaN                Extinct
# 2402                   ANG            kwz                Extinct
# 2403                   ANG            NaN                Extinct
#
#      Alternate names Name in the language  Number of speakers  \
# 891              NaN                  NaN              2627.0
# 2385             NaN                  NaN                 0.0
# 2402             NaN                  NaN                 0.0
# ...

# %%
cdf['Country codes alpha 3'].replace('ANG','AGO', inplace=True)
cdf
# Out:
# c:\users\warui\appdata\local\programs\python\python38\lib\site-packages\pandas\core\generic.py:6610: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)
#        ID Name in English Name in French Name in Spanish Countries  \
# 891   127            Bolo           bolo            bolo    Angola
# 2385  126            Kede           kede            kede    Angola
# 2402  124           Kwadi          kwadi           kuadí    Angola
# 2403  125           Kwisi          kwisi           kwisi    Angola
#
#      Country codes alpha 3 ISO639-3 codes Degree of endangerment  \
# 891                    AGO            blv  Definitely endangered
# 2385                   AGO            NaN                Extinct
# 2402                   AGO            kwz                Extinct
# ...
